# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style

# %%
df=pd.read_csv('Book1.csv')

# %%
df
# Out:
#      AFG               Afghanistan    2019    13162    26     9    48    43  \
# 0    ALB                   Albania  2019.0    503.0  61.0  15.0  32.0  54.0
# 1    DZA                   Algeria  2019.0   9098.0  73.0   6.0  46.0  48.0
# 2    AND                   Andorra  2019.0     19.0  88.0  19.0  39.0  42.0
# 3    AGO                    Angola  2019.0  12368.0  66.0  17.0  46.0  37.0
# 4    ATG       Antigua and Barbuda  2019.0     20.0  25.0  15.0  49.0  35.0
# ..   ...                       ...     ...      ...   ...   ...   ...   ...
# 162  PSE  West Bank and Gaza Strip  2019.0   1644.0  76.0  16.0  29.0  55.0
# 163  YEM                     Yemen  2019.0  10660.0  37.0  22.0  41.0  37.0
# 164  ZMB                    Zambia  2019.0   7882.0  44.0  29.0  44.0  27.0
# 165  ZWE                  Zimbabwe  2019.0   5764.0  32.0  15.0  50.0  35.0
# 166  NaN                       NaN     NaN      NaN   NaN   NaN   NaN   NaN
#
#       66   13  ... -.25 -.26 -.27 -.28    3 -.29 -.30   10 -.31 -.32
# 0     59    -  ...    -    -    -    -   71    -    -   84    -    -
# 1     92   <1  ...    -    -    -    -   98    -    -  >99    -    -
# 2    >99   <1  ...    -    -    -    -  >99   <1   <1  >99   <1   <1
# 3      -    -  ...    -    -    -    -    -    -    -    -    -    -
# 4    >99   <1  ...    -    -    -    -  >99   <1   <1  >99   <1   <1
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 162   78   22  ...    4    -    -    -   22   73    5   29   66    5
# 163    -    -  ...    -    -    -    -    -    -    -    -    -    -
# 164   79    4  ...   52    -    -    -   55    -    -   58    -    -
# 165   66   21  ...   42    -    -   35    -    -   37    -    -   41
# 166  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [167 rows x 62 columns]

# %%
col_names=['ISO Code','Countries and areas','Year','School age population (thousands)','% urban', '% pre-primary', '% primary','% secondary', 'NATIONAL Basic water service','NATIONAL Limited water service', 'NATIONAL No water service', 
           'URBAN Basic water service','URBAN Limited water service', 'URBAN No water service',
          'RURAL Basic water service','RURAL Limited water service', 'RURAL No water service',
          'PRE-PRIMARY Basic water service','PRE-PRIMARY Limited water service', 'PRE-PRIMARY No water service',
          'PRIMARY Basic water service','PRIMARY Limited water service', 'PRIMARY No water service',
          'SECONDARY Basic water service','SECONDARY Limited water service', 'SECONDARY No water service',
          'NATIONAL Basic sanitation service','NATIONAL Limited sanitation service', 'NATIONAL No sanitation service',
          'URBAN Basic sanitation service','URBAN Limited sanitation service', 'URBAN No sanitation service',
          'RURAL Basic sanitation service','RURAL Limited sanitation service', 'RURAL No sanitation service',
          'PRE-PRIMARY Basic sanitation service','PRE-PRIMARY Limited sanitation service', 'PRE-PRIMARY No sanitation service',
          'PRIMARY Basic sanitation service','PRIMARY Limited sanitation service', 'PRIMARY No sanitation service',
          'SECONDARY Basic sanitation service','SECONDARY Limited sanitation service', 'SECONDARY No sanitation service',
          'NATIONAL Basic hygine service','NATIONAL Limited hygine service', 'NATIONAL No hygine service',
          'URBAN Basic hygine service','URBAN Limited hygine service', 'URBAN No hygine service',
          'RURAL Basic hygine service','RURAL Limited hygine service', 'RURAL No hygine service',
          'PRE-PRIMARY Basic hygine service','PRE-PRIMARY Limited hygine service', 'PRE-PRIMARY No hygine service',
          'PRIMARY Basic hygine service','PRIMARY Limited hygine service', 'PRIMARY No hygine service',
          'SECONDARY Basic hygine service','SECONDARY Limited hygine service', 'SECONDARY No hygine service']

# %%
df_temp = pd.read_csv('Book1.csv',index_col=0,names=col_names,)

# %%
df_temp
# Out:
#                Countries and areas    Year  School age population (thousands)  \
# ISO Code
# AFG                    Afghanistan  2019.0                            13162.0
# ALB                        Albania  2019.0                              503.0
# DZA                        Algeria  2019.0                             9098.0
# AND                        Andorra  2019.0                               19.0
# AGO                         Angola  2019.0                            12368.0
# ...                            ...     ...                                ...
# PSE       West Bank and Gaza Strip  2019.0                             1644.0
# YEM                          Yemen  2019.0                            10660.0
# ZMB                         Zambia  2019.0                             7882.0
# ZWE                       Zimbabwe  2019.0                             5764.0
# NaN                            NaN     NaN                                NaN
#
#           % urban  % pre-primary  % primary  % secondary  \
# ISO Code
# AFG          26.0            9.0       48.0         43.0
# ALB          61.0           15.0       32.0         54.0
# DZA          73.0            6.0       46.0         48.0
# AND          88.0           19.0       39.0         42.0
# AGO          66.0           17.0       46.0         37.0
# ...           ...            ...        ...          ...
# PSE          76.0           16.0       29.0         55.0
# YEM          37.0           22.0       41.0         37.0
# ZMB          44.0           29.0       44.0         27.0
# ZWE          32.0           15.0       50.0         35.0
# NaN           NaN            NaN        NaN          NaN
#
#          NATIONAL Basic water service NATIONAL Limited water service  \
# ISO Code
# AFG                                66                             13
# ALB                                59                              -
# DZA                                92                             <1
# AND                               >99                             <1
# AGO                                 -                              -
# ...                               ...                            ...
# PSE                                78                             22
# YEM                                 -                              -
# ZMB                                79                              4
# ZWE                                66                             21
# NaN                               NaN                            NaN
#
#          NATIONAL No water service  ... RURAL No hygine service  \
# ISO Code                            ...
# AFG                             22  ...                       -
# ALB                              -  ...                       -
# DZA                              8  ...                       -
# AND                             <1  ...                       -
# AGO                             68  ...                       -
# ...                            ...  ...                     ...
# PSE                             <1  ...                       4
# YEM                              -  ...                       -
# ZMB                             17  ...                      52
# ZWE                             13  ...                      42
# NaN                            NaN  ...                     NaN
#
#          PRE-PRIMARY Basic hygine service PRE-PRIMARY Limited hygine service  \
# ISO Code
# AFG                                     -                                  -
# ALB                                     -                                  -
# DZA                                     -                                  -
# AND                                     -                                  -
# AGO                                     -                                  -
# ...                                   ...                                ...
# PSE                                     -                                  -
# YEM                                     -                                  -
# ZMB                                     -                                  -
# ZWE                                     -                                  -
# NaN                                   NaN                                NaN
#
#          PRE-PRIMARY No hygine service PRIMARY Basic hygine service  \
# ISO Code
# AFG                                  -                            3
# ALB                                  -                           71
# DZA                                  -                           98
# AND                                  -                          >99
# AGO                                  -                            -
# ...                                ...                          ...
# PSE                                  -                           22
# YEM                                  -                            -
# ZMB                                  -                           55
# ZWE                                 35                            -
# NaN                                NaN                          NaN
#
#          PRIMARY Limited hygine service PRIMARY No hygine service  \
# ISO Code
# AFG                                   -                         -
# ALB                                   -                         -
# DZA                                   -                         -
# AND                                  <1                        <1
# AGO                                   -                         -
# ...                                 ...                       ...
# PSE                                  73                         5
# YEM                                   -                         -
# ZMB                                   -                         -
# ZWE                                   -                        37
# NaN                                 NaN                       NaN
#
#          SECONDARY Basic hygine service SECONDARY Limited hygine service  \
# ISO Code
# AFG                                  10                                -
# ALB                                  84                                -
# DZA                                 >99                                -
# AND                                 >99                               <1
# AGO                                   -                                -
# ...                                 ...                              ...
# PSE                                  29                               66
# YEM                                   -                                -
# ZMB                                  58                                -
# ZWE                                   -                                -
# NaN                                 NaN                              NaN
#
#          SECONDARY No hygine service
# ISO Code
# AFG                                -
# ALB                                -
# DZA                                -
# AND                               <1
# AGO                                -
# ...                              ...
# PSE                                5
# YEM                                -
# ZMB                                -
# ZWE                               41
# NaN                              NaN
#
# [168 rows x 61 columns]

# %%
df_temp = df_temp.fillna(0) # to fill the NAN values as 0

# %%
float_col = df_temp.select_dtypes(include=['float64']) # to find out the float values in the dataset

# %%
float_col
# Out:
#             Year  School age population (thousands)  % urban  % pre-primary  \
# ISO Code
# AFG       2019.0                            13162.0     26.0            9.0
# ALB       2019.0                              503.0     61.0           15.0
# DZA       2019.0                             9098.0     73.0            6.0
# AND       2019.0                               19.0     88.0           19.0
# AGO       2019.0                            12368.0     66.0           17.0
# ...          ...                                ...      ...            ...
# PSE       2019.0                             1644.0     76.0           16.0
# YEM       2019.0                            10660.0     37.0           22.0
# ZMB       2019.0                             7882.0     44.0           29.0
# ZWE       2019.0                             5764.0     32.0           15.0
# NaN          0.0                                0.0      0.0            0.0
#
#           % primary  % secondary
# ISO Code
# AFG            48.0         43.0
# ALB            32.0         54.0
# DZA            46.0         48.0
# AND            39.0         42.0
# AGO            46.0         37.0
# ...             ...          ...
# PSE            29.0         55.0
# YEM            41.0         37.0
# ZMB            44.0         27.0
# ZWE            50.0         35.0
# NaN             0.0          0.0
#
# [168 rows x 6 columns]

# %%
df_temp["% urban"] = df_temp ["% urban"].astype(int)
df_temp["Year"] = df_temp ["Year"].astype(int)
df_temp["School age population (thousands)"] = df_temp ["School age population (thousands)"].astype(int)
df_temp["% pre-primary"] = df_temp ["% pre-primary"].astype(int)
df_temp["% primary"] = df_temp ["% primary"].astype(int)

# to convert all the float values into int

# %%
df_temp
# Out:
#                Countries and areas  Year  School age population (thousands)  \
# ISO Code
# AFG                    Afghanistan  2019                              13162
# ALB                        Albania  2019                                503
# DZA                        Algeria  2019                               9098
# AND                        Andorra  2019                                 19
# AGO                         Angola  2019                              12368
# ...                            ...   ...                                ...
# PSE       West Bank and Gaza Strip  2019                               1644
# YEM                          Yemen  2019                              10660
# ZMB                         Zambia  2019                               7882
# ZWE                       Zimbabwe  2019                               5764
# NaN                              0     0                                  0
#
#           % urban  % pre-primary  % primary  % secondary  \
# ISO Code
# AFG            26              9         48         43.0
# ALB            61             15         32         54.0
# DZA            73              6         46         48.0
# AND            88             19         39         42.0
# AGO            66             17         46         37.0
# ...           ...            ...        ...          ...
# PSE            76             16         29         55.0
# YEM            37             22         41         37.0
# ZMB            44             29         44         27.0
# ZWE            32             15         50         35.0
# NaN             0              0          0          0.0
#
#          NATIONAL Basic water service NATIONAL Limited water service  \
# ISO Code
# AFG                                66                             13
# ALB                                59                              -
# DZA                                92                             <1
# AND                               >99                             <1
# AGO                                 -                              -
# ...                               ...                            ...
# PSE                                78                             22
# YEM                                 -                              -
# ZMB                                79                              4
# ZWE                                66                             21
# NaN                                 0                              0
#
#          NATIONAL No water service  ... RURAL No hygine service  \
# ISO Code                            ...
# AFG                             22  ...                       -
# ALB                              -  ...                       -
# DZA                              8  ...                       -
# AND                             <1  ...                       -
# AGO                             68  ...                       -
# ...                            ...  ...                     ...
# PSE                             <1  ...                       4
# YEM                              -  ...                       -
# ZMB                             17  ...                      52
# ZWE                             13  ...                      42
# NaN                              0  ...                       0
#
#          PRE-PRIMARY Basic hygine service PRE-PRIMARY Limited hygine service  \
# ISO Code
# AFG                                     -                                  -
# ALB                                     -                                  -
# DZA                                     -                                  -
# AND                                     -                                  -
# AGO                                     -                                  -
# ...                                   ...                                ...
# PSE                                     -                                  -
# YEM                                     -                                  -
# ZMB                                     -                                  -
# ZWE                                     -                                  -
# NaN                                     0                                  0
#
#          PRE-PRIMARY No hygine service PRIMARY Basic hygine service  \
# ISO Code
# AFG                                  -                            3
# ALB                                  -                           71
# DZA                                  -                           98
# AND                                  -                          >99
# AGO                                  -                            -
# ...                                ...                          ...
# PSE                                  -                           22
# YEM                                  -                            -
# ZMB                                  -                           55
# ZWE                                 35                            -
# NaN                                  0                            0
#
#          PRIMARY Limited hygine service PRIMARY No hygine service  \
# ISO Code
# AFG                                   -                         -
# ALB                                   -                         -
# DZA                                   -                         -
# AND                                  <1                        <1
# AGO                                   -                         -
# ...                                 ...                       ...
# PSE                                  73                         5
# YEM                                   -                         -
# ZMB                                   -                         -
# ZWE                                   -                        37
# NaN                                   0                         0
#
#          SECONDARY Basic hygine service SECONDARY Limited hygine service  \
# ISO Code
# AFG                                  10                                -
# ALB                                  84                                -
# DZA                                 >99                                -
# AND                                 >99                               <1
# AGO                                   -                                -
# ...                                 ...                              ...
# PSE                                  29                               66
# YEM                                   -                                -
# ZMB                                  58                                -
# ZWE                                   -                                -
# NaN                                   0                                0
#
#          SECONDARY No hygine service
# ISO Code
# AFG                                -
# ALB                                -
# DZA                                -
# AND                               <1
# AGO                                -
# ...                              ...
# PSE                                5
# YEM                                -
# ZMB                                -
# ZWE                               41
# NaN                                0
#
# [168 rows x 61 columns]

# %%
df_temp.plot(x='Countries and areas', y='% primary')  #plot
# Out:
# <AxesSubplot:xlabel='Countries and areas'>
